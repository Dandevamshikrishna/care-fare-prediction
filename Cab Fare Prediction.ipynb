# %%
import numpy as np
import pandas as pd

# %%
df_train = pd.read_csv("TRAIN.csv")

# %%
df_train.shape
# Out:
# (100000, 9)

# %%
df_train.dtypes
# Out:
# index                 int64
# time_stamp            int64
# cab_provider         object
# source               object
# destination          object
# distance            float64
# surge_multiplier    float64
# cab_type             object
# fare                float64
# dtype: object

# %%
df_train['time_stamp'] = pd.to_datetime(df_train['time_stamp'], unit = 'ms')

# %%
df_train.head()
# Out:
#    index              time_stamp cab_provider                   source  \
# 0      0 2018-11-26 03:40:46.318         Lyft        Boston University
# 1      1 2018-11-26 03:40:46.319         Uber            South Station
# 2      2 2018-11-26 03:40:46.320         Uber         Theatre District
# 3      3 2018-11-26 03:40:46.320         Lyft  Northeastern University
# 4      4 2018-11-26 03:40:46.320         Uber         Theatre District
#
#         destination  distance  surge_multiplier      cab_type  fare
# 0  Theatre District      3.03               1.0  Lux Black XL  34.0
# 1  Theatre District      1.30               1.0         Black  18.5
# 2            Fenway      2.71               1.0         UberX  19.5
# 3       Beacon Hill      2.43               1.0          Lyft  10.5
# 4            Fenway      2.71               1.0        UberXL  32.0

# %%
df_train['time_stamp'].value_counts()
# Out:
# 2018-11-26 22:14:10.151    50
# 2018-11-26 16:11:10.078    39
# 2018-11-26 22:11:10.438    39
# 2018-11-26 10:08:10.179    38
# 2018-11-27 00:21:14.367    29
#                            ..
# 2018-11-26 20:32:10.090     1
# 2018-11-27 13:45:24.025     1
# 2018-11-27 08:12:23.228     1
# 2018-11-26 07:18:17.265     1
# 2018-11-27 16:21:23.733     1
# Name: time_stamp, Length: 17958, dtype: int64

# %%
df_train.dtypes
# Out:
# index                        int64
# time_stamp          datetime64[ns]
# cab_provider                object
# source                      object
# destination                 object
# distance                   float64
# surge_multiplier           float64
# cab_type                    object
# fare                       float64
# dtype: object

# %%
df_train.isnull().sum()
# Out:
# index               0
# time_stamp          0
# cab_provider        0
# source              0
# destination         0
# distance            0
# surge_multiplier    0
# cab_type            0
# fare                0
# dtype: int64

# %%
df_test = pd.read_csv("TEST.csv")

# %%
df_test.shape
# Out:
# (25000, 8)

# %%
df_test['time_stamp'] = pd.to_datetime(df_test['time_stamp'], unit = 'ms')

# %%
df_test.head()
# Out:
#    index              time_stamp cab_provider              source  \
# 0      0 2018-11-28 00:15:24.206         Lyft    Theatre District
# 1      1 2018-11-28 00:15:24.206         Lyft    Theatre District
# 2      2 2018-11-28 00:15:24.206         Uber  Financial District
# 3      3 2018-11-28 00:15:24.206         Uber         Beacon Hill
# 4      4 2018-11-28 00:15:24.206         Lyft    Theatre District
#
#         destination  distance  surge_multiplier      cab_type
# 0     South Station      0.59               1.0           Lux
# 1     South Station      0.59               1.0  Lux Black XL
# 2            Fenway      6.83               1.0         UberX
# 3  Haymarket Square      1.35               1.0        UberXL
# 4     South Station      0.59               1.0       Lyft XL

# %%
df_train['surge_multiplier'].value_counts()
# Out:
# 1.00    96753
# 1.25     1715
# 1.50      764
# 1.75      403
# 2.00      337
# 2.50       23
# 3.00        5
# Name: surge_multiplier, dtype: int64

# %%
df_train["day"] = pd.to_datetime(df_train.time_stamp, format="%Y-%m-%d").dt.day
df_train.head()
# Out:
#    index              time_stamp cab_provider                   source  \
# 0      0 2018-11-26 03:40:46.318         Lyft        Boston University
# 1      1 2018-11-26 03:40:46.319         Uber            South Station
# 2      2 2018-11-26 03:40:46.320         Uber         Theatre District
# 3      3 2018-11-26 03:40:46.320         Lyft  Northeastern University
# 4      4 2018-11-26 03:40:46.320         Uber         Theatre District
#
#         destination  distance  surge_multiplier      cab_type  fare  day
# 0  Theatre District      3.03               1.0  Lux Black XL  34.0   26
# 1  Theatre District      1.30               1.0         Black  18.5   26
# 2            Fenway      2.71               1.0         UberX  19.5   26
# 3       Beacon Hill      2.43               1.0          Lyft  10.5   26
# 4            Fenway      2.71               1.0        UberXL  32.0   26

# %%
df_train["hour"] = pd.to_datetime(df_train.time_stamp, format="%Y-%m-%d").dt.hour
df_train.head()
# Out:
#    index              time_stamp cab_provider                   source  \
# 0      0 2018-11-26 03:40:46.318         Lyft        Boston University
# 1      1 2018-11-26 03:40:46.319         Uber            South Station
# 2      2 2018-11-26 03:40:46.320         Uber         Theatre District
# 3      3 2018-11-26 03:40:46.320         Lyft  Northeastern University
# 4      4 2018-11-26 03:40:46.320         Uber         Theatre District
#
#         destination  distance  surge_multiplier      cab_type  fare  day  hour
# 0  Theatre District      3.03               1.0  Lux Black XL  34.0   26     3
# 1  Theatre District      1.30               1.0         Black  18.5   26     3
# 2            Fenway      2.71               1.0         UberX  19.5   26     3
# 3       Beacon Hill      2.43               1.0          Lyft  10.5   26     3
# 4            Fenway      2.71               1.0        UberXL  32.0   26     3

# %%
df_train["min"] = pd.to_datetime(df_train.time_stamp, format="%Y-%m-%d").dt.minute
df_train.head()
# Out:
#    index              time_stamp cab_provider                   source  \
# 0      0 2018-11-26 03:40:46.318         Lyft        Boston University
# 1      1 2018-11-26 03:40:46.319         Uber            South Station
# 2      2 2018-11-26 03:40:46.320         Uber         Theatre District
# 3      3 2018-11-26 03:40:46.320         Lyft  Northeastern University
# 4      4 2018-11-26 03:40:46.320         Uber         Theatre District
#
#         destination  distance  surge_multiplier      cab_type  fare  day  \
# 0  Theatre District      3.03               1.0  Lux Black XL  34.0   26
# 1  Theatre District      1.30               1.0         Black  18.5   26
# 2            Fenway      2.71               1.0         UberX  19.5   26
# 3       Beacon Hill      2.43               1.0          Lyft  10.5   26
# 4            Fenway      2.71               1.0        UberXL  32.0   26
#
#    hour  min
# 0     3   40
# 1     3   40
# 2     3   40
# 3     3   40
# 4     3   40

# %%
df_train["sec"] = pd.to_datetime(df_train.time_stamp, format="%Y-%m-%d").dt.second
df_train.head()
# Out:
#    index              time_stamp cab_provider                   source  \
# 0      0 2018-11-26 03:40:46.318         Lyft        Boston University
# 1      1 2018-11-26 03:40:46.319         Uber            South Station
# 2      2 2018-11-26 03:40:46.320         Uber         Theatre District
# 3      3 2018-11-26 03:40:46.320         Lyft  Northeastern University
# 4      4 2018-11-26 03:40:46.320         Uber         Theatre District
#
#         destination  distance  surge_multiplier      cab_type  fare  day  \
# 0  Theatre District      3.03               1.0  Lux Black XL  34.0   26
# 1  Theatre District      1.30               1.0         Black  18.5   26
# 2            Fenway      2.71               1.0         UberX  19.5   26
# 3       Beacon Hill      2.43               1.0          Lyft  10.5   26
# 4            Fenway      2.71               1.0        UberXL  32.0   26
#
#    hour  min  sec
# 0     3   40   46
# 1     3   40   46
# 2     3   40   46
# 3     3   40   46
# ...

# %%
df_train['day'].value_counts()
# Out:
# 27    70135
# 26    29028
# 28      837
# Name: day, dtype: int64

# %%
df_train['hour'].value_counts()
# Out:
# 23    5753
# 22    5258
# 0     4580
# 17    4447
# 20    4440
# 19    4440
# 13    4438
# 18    4431
# 16    4428
# 12    4427
# 21    4414
# 15    4412
# 14    4412
# 10    4403
# 9     4402
# 11    4389
# 6     4340
# 7     3800
# 5     3464
# 4     3267
# 1     3150
# 8     3088
# 3     2939
# 2     2878
# Name: hour, dtype: int64

# %%
df_train.drop(['time_stamp', 'index'], axis = 1, inplace = True)

# %%
df_train.head()
# Out:
#   cab_provider                   source       destination  distance  \
# 0         Lyft        Boston University  Theatre District      3.03
# 1         Uber            South Station  Theatre District      1.30
# 2         Uber         Theatre District            Fenway      2.71
# 3         Lyft  Northeastern University       Beacon Hill      2.43
# 4         Uber         Theatre District            Fenway      2.71
#
#    surge_multiplier      cab_type  fare  day  hour  min  sec
# 0               1.0  Lux Black XL  34.0   26     3   40   46
# 1               1.0         Black  18.5   26     3   40   46
# 2               1.0         UberX  19.5   26     3   40   46
# 3               1.0          Lyft  10.5   26     3   40   46
# 4               1.0        UberXL  32.0   26     3   40   46

# %%
df_train.dtypes
# Out:
# cab_provider         object
# source               object
# destination          object
# distance            float64
# surge_multiplier    float64
# cab_type             object
# fare                float64
# day                   int64
# hour                  int64
# min                   int64
# sec                   int64
# dtype: object

# %%
df_train['source'].value_counts()
# Out:
# North End                  8637
# Financial District         8540
# Theatre District           8445
# South Station              8423
# Back Bay                   8375
# Haymarket Square           8337
# Northeastern University    8333
# Fenway                     8277
# Beacon Hill                8277
# Boston University          8231
# West End                   8192
# North Station              7933
# Name: source, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# source vs Price
sns.catplot(y = "fare", x = "cab_type", data = df_train.sort_values("fare", ascending = False), kind="boxen", height = 6, aspect = 3)
plt.show()

# %%
# source vs Price
sns.catplot(y = "fare", x = "source", data = df_train.sort_values("fare", ascending = False), kind="boxen", height = 6, aspect = 3)
plt.show()

# %%
# source vs Price
sns.catplot(y = "fare", x = "cab_provider", data = df_train.sort_values("fare", ascending = False), kind="boxen", height = 6, aspect = 3)
plt.show()

# %%
df_train['distance'].max()
# Out:
# 7.5

# %%
df_train[df_train['distance'] == 7.5]
# Out:
#       cab_provider  source         destination  distance  surge_multiplier  \
# 53724         Uber  Fenway  Financial District       7.5               1.0
# 53725         Uber  Fenway  Financial District       7.5               1.0
# 53727         Uber  Fenway  Financial District       7.5               1.0
# 53728         Uber  Fenway  Financial District       7.5               1.0
# 53729         Uber  Fenway  Financial District       7.5               1.0
# 62521         Uber  Fenway  Financial District       7.5               1.0
# 91945         Uber  Fenway  Financial District       7.5               1.0
# 99235         Uber  Fenway  Financial District       7.5               1.0
# 99238         Uber  Fenway  Financial District       7.5               1.0
#
#         cab_type  fare  day  hour  min  sec
# 53724     UberXL  26.0   27     8   12   21
# 53725   UberPool  16.5   27     8   12   21
# 53727        WAV  17.0   27     8   12   21
# ...

# %%
df_train['fare'].max()
# Out:
# 92.0

# %%
df_train[df_train['fare'] == 92]
# Out:
#       cab_provider              source         destination  distance  \
# 79188         Lyft   Boston University  Financial District      3.75
# 93548         Lyft  Financial District   Boston University      5.39
#
#        surge_multiplier      cab_type  fare  day  hour  min  sec
# 79188               2.0  Lux Black XL  92.0   27    17    3   22
# 93548               2.0  Lux Black XL  92.0   27    22    3   21

# %%
plt.figure(figsize=(12,6))
df_train.corr()['fare'].sort_values().plot(kind='bar');

# %%
plt.figure(figsize=(12,6))
sns.countplot(df_train['cab_type'], palette='Set3')
plt.title('Count of cab_type', size=30)
plt.xticks(rotation=90)
plt.show()
# Out:
# F:\app\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,6))
sns.countplot(df_train['day'], palette='Set2')
plt.title('Count of Days', size=30)
plt.xticks(rotation=90)
plt.show()
# Out:
# F:\app\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,6))
sns.barplot(df_train['day'], df_train['fare'], palette='Set2')
plt.title('Days vs fare', size=30)
plt.xticks(rotation=90)
plt.show()
# Out:
# F:\app\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(df_train['hour'], df_train['fare'], palette='Set2')
plt.title('hour vs fare', size=30)
plt.xticks(rotation=90)
plt.show()
# Out:
# F:\app\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df_train.isnull().sum()
# Out:
# cab_provider        0
# source              0
# destination         0
# distance            0
# surge_multiplier    0
# cab_type            0
# fare                0
# day                 0
# hour                0
# min                 0
# sec                 0
# dtype: int64

# %%
cor = df_train.corr()

# %%
#fare the predictor variable (Numeric)
sns.distplot(df_train['fare'])
plt.show()
# Out:
# F:\app\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# Figure size
plt.figure(figsize=(16,8))

# Heatmap
sns.heatmap(cor, cmap="PiYG", annot=True)
plt.show()

# %%
df_train.drop("sec", axis = 1, inplace = True)

# %%
cor1 = df_train.corr()

# %%
# Figure size
plt.figure(figsize=(16,8))

# Heatmap
sns.heatmap(cor1, cmap="PiYG", annot=True)
plt.show()

# %%
# Pairwise scatter plot

plt.figure(figsize=(20, 10))
sns.pairplot(df_train)
plt.show()

# %%
# Subset all categorical variables
df_train_categorical = df_train.select_dtypes(include=['object'])
df_train_categorical.head()
# Out:
#   cab_provider                   source       destination      cab_type
# 0         Lyft        Boston University  Theatre District  Lux Black XL
# 1         Uber            South Station  Theatre District         Black
# 2         Uber         Theatre District            Fenway         UberX
# 3         Lyft  Northeastern University       Beacon Hill          Lyft
# 4         Uber         Theatre District            Fenway        UberXL

# %%
# Checking the different levels of 'doornumber'
df_train['cab_type'].astype('category').value_counts()
# Out:
# Black           8744
# Black SUV       8712
# UberXL          8676
# UberX           8588
# WAV             8585
# UberPool        8558
# Lyft XL         8115
# Lux Black XL    8065
# Lux             8060
# Shared          7998
# Lyft            7957
# Lux Black       7942
# Name: cab_type, dtype: int64

# %%
plt.figure(figsize=(12,6))
sns.catplot(x="cab_type", y="fare", kind="box", data=df_train)
plt.title('cab_type vs fare', size=30)
plt.xticks(rotation=90)
plt.show()

# %%
# A function to map the categorical levels to actual numbers. You can see the categorical levels above and use them for mapping.
def num_map(x):
    return x.map({'Black SUV': 12, "Lux Black XL": 11, "Lux Black": 10, "Black": 9, "Lux": 8, "Lyft XL": 7,
                  "UberXL": 6, "Lyft":5, "UberX":4, "WAV":3, "UberPool":2,"Shared":1})

# %%
df_train[['cab_type']] = df_train[['cab_type']].apply(num_map)

# %%
df_train.head()
# Out:
#   cab_provider                   source       destination  distance  \
# 0         Lyft        Boston University  Theatre District      3.03
# 1         Uber            South Station  Theatre District      1.30
# 2         Uber         Theatre District            Fenway      2.71
# 3         Lyft  Northeastern University       Beacon Hill      2.43
# 4         Uber         Theatre District            Fenway      2.71
#
#    surge_multiplier  cab_type  fare  day  hour  min
# 0               1.0        11  34.0   26     3   40
# 1               1.0         9  18.5   26     3   40
# 2               1.0         4  19.5   26     3   40
# 3               1.0         5  10.5   26     3   40
# 4               1.0         6  32.0   26     3   40

# %%
sns.scatterplot(data=df_train, y="fare", x="cab_type")
# Out:
# <AxesSubplot:xlabel='cab_type', ylabel='fare'>

# %%
df_train_categorical.drop('cab_type', axis = 1, inplace = True)
# Out:
# F:\app\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_train_categorical.head()
# Out:
#   cab_provider                   source       destination
# 0         Lyft        Boston University  Theatre District
# 1         Uber            South Station  Theatre District
# 2         Uber         Theatre District            Fenway
# 3         Lyft  Northeastern University       Beacon Hill
# 4         Uber         Theatre District            Fenway

# %%
# Convert into dummies
df_train_dummies = pd.get_dummies(df_train_categorical, drop_first=True)
df_train_dummies.head()
# Out:
#    cab_provider_Uber  source_Beacon Hill  source_Boston University  \
# 0                  0                   0                         1
# 1                  1                   0                         0
# 2                  1                   0                         0
# 3                  0                   0                         0
# 4                  1                   0                         0
#
#    source_Fenway  source_Financial District  source_Haymarket Square  \
# 0              0                          0                        0
# 1              0                          0                        0
# 2              0                          0                        0
# 3              0                          0                        0
# 4              0                          0                        0
#
#    source_North End  source_North Station  source_Northeastern University  \
# ...

# %%
# Drop categ# Concatenate dummy variables with X
df_train = pd.concat([df_train, df_train_dummies], axis=1)
df_train = df_train.drop(list(df_train_categorical.columns), axis=1)

# %%
df_train.head()
# Out:
#    distance  surge_multiplier  cab_type  fare  day  hour  min  \
# 0      3.03               1.0        11  34.0   26     3   40
# 1      1.30               1.0         9  18.5   26     3   40
# 2      2.71               1.0         4  19.5   26     3   40
# 3      2.43               1.0         5  10.5   26     3   40
# 4      2.71               1.0         6  32.0   26     3   40
#
#    cab_provider_Uber  source_Beacon Hill  source_Boston University  ...  \
# 0                  0                   0                         1  ...
# 1                  1                   0                         0  ...
# 2                  1                   0                         0  ...
# 3                  0                   0                         0  ...
# 4                  1                   0                         0  ...
#
#    destination_Boston University  destination_Fenway  \
# 0                              0                   0
# ...

# %%
# Split the datafram into train and test sets
from sklearn.model_selection import train_test_split
train, test = train_test_split(df_train, train_size=0.7, test_size=0.3, random_state=100)

# %%
# All numeric (float and int) variables in the dataset
df_train_numeric = df_train.select_dtypes(include=['float64', 'int64'])
df_train_numeric.head()
# Out:
#    distance  surge_multiplier  cab_type  fare  day  hour  min
# 0      3.03               1.0        11  34.0   26     3   40
# 1      1.30               1.0         9  18.5   26     3   40
# 2      2.71               1.0         4  19.5   26     3   40
# 3      2.43               1.0         5  10.5   26     3   40
# 4      2.71               1.0         6  32.0   26     3   40

# %%
df_train_numeric.columns
# Out:
# Index(['distance', 'surge_multiplier', 'cab_type', 'fare', 'day', 'hour',
#        'min'],
#       dtype='object')

# %%
# Import the StandardScaler()
from sklearn.preprocessing import StandardScaler

# Create a scaling object
scaler = StandardScaler()

# Create a list of the variables that you need to scale
varlist = ['distance', 'surge_multiplier', 'cab_type', 'fare', 'day', 'hour',
       'min']

# Scale these variables using 'fit_transform'
train[varlist] = scaler.fit_transform(train[varlist])
# Out:
# <ipython-input-61-a2db5a48bdce>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train[varlist] = scaler.fit_transform(train[varlist])
# F:\app\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
# Let's take a look at the train dataframe now
train.head()
# Out:
#        distance  surge_multiplier  cab_type      fare       day      hour  \
# 78763 -1.571557         -0.156615  1.594442  1.171460  0.603990  0.521771
# 71947 -1.361785         -0.156615  0.725901 -0.167004  0.603990  0.232179
# 21641 -0.015751         -0.156615  0.725901  0.154227 -1.530251  1.100957
# 61078  0.071653         -0.156615  0.725901  0.261304  0.603990 -0.347006
# 14736  0.106615          5.101451  1.304928  3.098848 -1.530251  0.521771
#
#             min  cab_provider_Uber  source_Beacon Hill  \
# 78763  1.449219                  1                   0
# 71947  0.232847                  1                   0
# 21641  0.522460                  1                   0
# 61078  0.927917                  1                   1
# 14736 -1.041447                  0                   0
#
#        source_Boston University  ...  destination_Boston University  \
# 78763                         0  ...                              0
# ...

# %%
# Split the train dataset into X and y

y_train = train.pop('fare')
X_train = train

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression

# %%
# Instantiate
lm = LinearRegression()

# Fit a line
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# Print the coefficients and intercept
print(lm.coef_)
print(lm.intercept_)
# Out:
# [ 3.54765348e-01  1.77557903e-01  8.34615119e-01  6.43379798e-04
#   8.77477220e-04 -1.39359270e-03  1.32550769e-01 -3.30084461e-02
#  -1.98639272e+11 -1.98639272e+11  3.31950169e-02 -1.98639272e+11
#  -1.98639272e+11  3.70239089e-04 -1.98639272e+11 -1.98639272e+11
#   5.52523537e-02  5.87665747e-03 -3.65975147e-02 -1.98639272e+11
#  -1.98639272e+11  4.10878150e-02 -1.98639272e+11 -1.98639272e+11
#   2.40029855e-02 -1.98639272e+11 -1.98639272e+11  2.11371267e-02
#  -3.20163604e-03]
# 198639271774.06174

# %%
# Import statsmodels
import statsmodels.api as sm 
# Add a constant to the model
X_train_1 = sm.add_constant(X_train)
X_train_1.head()
# Out:
#        const  distance  surge_multiplier  cab_type       day      hour  \
# 78763    1.0 -1.571557         -0.156615  1.594442  0.603990  0.521771
# 71947    1.0 -1.361785         -0.156615  0.725901  0.603990  0.232179
# 21641    1.0 -0.015751         -0.156615  0.725901 -1.530251  1.100957
# 61078    1.0  0.071653         -0.156615  0.725901  0.603990 -0.347006
# 14736    1.0  0.106615          5.101451  1.304928 -1.530251  0.521771
#
#             min  cab_provider_Uber  source_Beacon Hill  \
# 78763  1.449219                  1                   0
# 71947  0.232847                  1                   0
# 21641  0.522460                  1                   0
# 61078  0.927917                  1                   1
# 14736 -1.041447                  0                   0
#
#        source_Boston University  ...  destination_Boston University  \
# 78763                         0  ...                              0
# ...

# %%
# Fitting the model with 15 variables
lm1 = sm.OLS(y_train, X_train_1).fit()   
print(lm1.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                   fare   R-squared:                       0.858
# Model:                            OLS   Adj. R-squared:                  0.858
# Method:                 Least Squares   F-statistic:                 1.508e+04
# Date:                Sun, 23 May 2021   Prob (F-statistic):               0.00
# Time:                        13:06:01   Log-Likelihood:                -31039.
# No. Observations:               70000   AIC:                         6.214e+04
# Df Residuals:                   69971   BIC:                         6.240e+04
# Df Model:                          28
# Covariance Type:            nonrobust
# ...
#                                           coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------------
# ...

# %%
test[varlist] = scaler.transform(test[varlist])
# Out:
# <ipython-input-69-2524dcba0d3c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test[varlist] = scaler.transform(test[varlist])
# F:\app\lib\site-packages\pandas\core\indexing.py:1736: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
test.head()
# Out:
#        distance  surge_multiplier  cab_type      fare       day      hour  \
# 22422  0.561120         -0.156615  0.436388  0.314843 -1.530251  1.245753
# 25747 -0.033232         -0.156615  1.304928  1.439153 -1.530251  1.390549
# 13795  1.679901         -0.156615  1.015415  1.706845 -1.530251  0.376975
# 68724  0.368830         -0.156615 -1.011180 -0.648851  0.603990  0.087382
# 38923 -1.003426         -0.156615 -0.721666 -0.755928  0.603990 -1.360580
#
#             min  cab_provider_Uber  source_Beacon Hill  \
# 22422 -1.215214                  0                   0
# 25747  1.449219                  0                   0
# 13795  0.174925                  0                   0
# 68724 -0.288455                  1                   0
# 38923 -1.678594                  1                   0
#
#        source_Boston University  ...  destination_Boston University  \
# 22422                         0  ...                              0
# ...

# %%
# Split the 'df_test' set into X and y
y_test = test.pop('fare')
X_test = test

# %%
# Making predictions
y_pred = lm.predict(X_test)

# %%
# r2_score for 6 variables
from sklearn.metrics import r2_score
r2_score(y_test, y_pred)
# Out:
# 0.8576371921538125

# %%
# Plotting y_test and y_pred to understand the spread

fig = plt.figure()
plt.scatter(y_test, y_pred)
fig.suptitle('y_test vs y_pred', fontsize = 20)              # Plot heading 
plt.xlabel('y_test', fontsize = 18)                          # X-label
plt.ylabel('y_pred', fontsize = 16)
# Out:
# Text(0, 0.5, 'y_pred')

# %%
from sklearn import metrics

# %%
print('MAE:', metrics.mean_absolute_error(y_test, y_pred))
print('MSE:', metrics.mean_squared_error(y_test, y_pred))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# MAE: 0.28611873140082567
# MSE: 0.141831967749386
# RMSE: 0.3766058519850508

# %%
X_test.head()
# Out:
#        distance  surge_multiplier  cab_type       day      hour       min  \
# 22422  0.561120         -0.156615  0.436388 -1.530251  1.245753 -1.215214
# 25747 -0.033232         -0.156615  1.304928 -1.530251  1.390549  1.449219
# 13795  1.679901         -0.156615  1.015415 -1.530251  0.376975  0.174925
# 68724  0.368830         -0.156615 -1.011180  0.603990  0.087382 -0.288455
# 38923 -1.003426         -0.156615 -0.721666  0.603990 -1.360580 -1.678594
#
#        cab_provider_Uber  source_Beacon Hill  source_Boston University  \
# 22422                  0                   0                         0
# 25747                  0                   0                         0
# 13795                  0                   0                         0
# 68724                  1                   0                         0
# 38923                  1                   0                         0
#
#        source_Fenway  ...  destination_Boston University  destination_Fenway  \
# ...

# %%
df_test.head()
# Out:
#    index              time_stamp cab_provider              source  \
# 0      0 2018-11-28 00:15:24.206         Lyft    Theatre District
# 1      1 2018-11-28 00:15:24.206         Lyft    Theatre District
# 2      2 2018-11-28 00:15:24.206         Uber  Financial District
# 3      3 2018-11-28 00:15:24.206         Uber         Beacon Hill
# 4      4 2018-11-28 00:15:24.206         Lyft    Theatre District
#
#         destination  distance  surge_multiplier      cab_type
# 0     South Station      0.59               1.0           Lux
# 1     South Station      0.59               1.0  Lux Black XL
# 2            Fenway      6.83               1.0         UberX
# 3  Haymarket Square      1.35               1.0        UberXL
# 4     South Station      0.59               1.0       Lyft XL

# %%
df_test.drop("index", inplace = True, axis = 1)

# %%
df_test.head()
# Out:
#                time_stamp cab_provider              source       destination  \
# 0 2018-11-28 00:15:24.206         Lyft    Theatre District     South Station
# 1 2018-11-28 00:15:24.206         Lyft    Theatre District     South Station
# 2 2018-11-28 00:15:24.206         Uber  Financial District            Fenway
# 3 2018-11-28 00:15:24.206         Uber         Beacon Hill  Haymarket Square
# 4 2018-11-28 00:15:24.206         Lyft    Theatre District     South Station
#
#    distance  surge_multiplier      cab_type
# 0      0.59               1.0           Lux
# 1      0.59               1.0  Lux Black XL
# 2      6.83               1.0         UberX
# 3      1.35               1.0        UberXL
# 4      0.59               1.0       Lyft XL

# %%
# Subset all categorical variables
df_test_categorical = df_test.select_dtypes(include=['object'])
df_test_categorical.head()
# Out:
#   cab_provider              source       destination      cab_type
# 0         Lyft    Theatre District     South Station           Lux
# 1         Lyft    Theatre District     South Station  Lux Black XL
# 2         Uber  Financial District            Fenway         UberX
# 3         Uber         Beacon Hill  Haymarket Square        UberXL
# 4         Lyft    Theatre District     South Station       Lyft XL

# %%
df_test[['cab_type']] = df_test[['cab_type']].apply(num_map)

# %%
df_test.head()
# Out:
#                time_stamp cab_provider              source       destination  \
# 0 2018-11-28 00:15:24.206         Lyft    Theatre District     South Station
# 1 2018-11-28 00:15:24.206         Lyft    Theatre District     South Station
# 2 2018-11-28 00:15:24.206         Uber  Financial District            Fenway
# 3 2018-11-28 00:15:24.206         Uber         Beacon Hill  Haymarket Square
# 4 2018-11-28 00:15:24.206         Lyft    Theatre District     South Station
#
#    distance  surge_multiplier  cab_type
# 0      0.59               1.0         8
# 1      0.59               1.0        11
# 2      6.83               1.0         4
# 3      1.35               1.0         6
# 4      0.59               1.0         7

# %%
df_test["day"] = pd.to_datetime(df_test.time_stamp, format="%Y-%m-%d").dt.day

df_test["hour"] = pd.to_datetime(df_test.time_stamp, format="%Y-%m-%d").dt.hour
df_test["min"] = pd.to_datetime(df_test.time_stamp, format="%Y-%m-%d").dt.minute

df_test["sec"] = pd.to_datetime(df_test.time_stamp, format="%Y-%m-%d").dt.second
df_test.head()
# Out:
#                time_stamp cab_provider              source       destination  \
# 0 2018-11-28 00:15:24.206         Lyft    Theatre District     South Station
# 1 2018-11-28 00:15:24.206         Lyft    Theatre District     South Station
# 2 2018-11-28 00:15:24.206         Uber  Financial District            Fenway
# 3 2018-11-28 00:15:24.206         Uber         Beacon Hill  Haymarket Square
# 4 2018-11-28 00:15:24.206         Lyft    Theatre District     South Station
#
#    distance  surge_multiplier  cab_type  day  hour  min  sec
# 0      0.59               1.0         8   28     0   15   24
# 1      0.59               1.0        11   28     0   15   24
# 2      6.83               1.0         4   28     0   15   24
# 3      1.35               1.0         6   28     0   15   24
# 4      0.59               1.0         7   28     0   15   24

# %%
df_test['hour'].value_counts()
# Out:
# 10    4607
# 12    4606
# 13    4604
# 11    4596
# 9     3291
# 0     2057
# 1      723
# 7      338
# 8      146
# 14      32
# Name: hour, dtype: int64

# %%
df_test.drop(['time_stamp'], axis = 1, inplace = True)

# %%
df_test.head()
# Out:
#   cab_provider              source       destination  distance  \
# 0         Lyft    Theatre District     South Station      0.59
# 1         Lyft    Theatre District     South Station      0.59
# 2         Uber  Financial District            Fenway      6.83
# 3         Uber         Beacon Hill  Haymarket Square      1.35
# 4         Lyft    Theatre District     South Station      0.59
#
#    surge_multiplier  cab_type  day  hour  min  sec
# 0               1.0         8   28     0   15   24
# 1               1.0        11   28     0   15   24
# 2               1.0         4   28     0   15   24
# 3               1.0         6   28     0   15   24
# 4               1.0         7   28     0   15   24

# %%
# Subset all categorical variables
df_test_categorical = df_test.select_dtypes(include=['object'])
df_test_categorical.head()
# Out:
#   cab_provider              source       destination
# 0         Lyft    Theatre District     South Station
# 1         Lyft    Theatre District     South Station
# 2         Uber  Financial District            Fenway
# 3         Uber         Beacon Hill  Haymarket Square
# 4         Lyft    Theatre District     South Station

# %%
#Convert into dummies
df_test_dummies = pd.get_dummies(df_test_categorical, drop_first=True)
df_test_dummies.head()
# Out:
#    cab_provider_Uber  source_Beacon Hill  source_Boston University  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  1                   0                         0
# 3                  1                   1                         0
# 4                  0                   0                         0
#
#    source_Fenway  source_Financial District  source_Haymarket Square  \
# 0              0                          0                        0
# 1              0                          0                        0
# 2              0                          1                        0
# 3              0                          0                        0
# 4              0                          0                        0
#
#    source_North End  source_North Station  source_Northeastern University  \
# ...

# %%
#Concatenate dummy variables with X
df_test = pd.concat([df_test, df_test_dummies], axis=1)
df_test = df_test.drop(list(df_test_categorical.columns), axis=1)

# %%
df_test.head()
# Out:
#    distance  surge_multiplier  cab_type  day  hour  min  sec  \
# 0      0.59               1.0         8   28     0   15   24
# 1      0.59               1.0        11   28     0   15   24
# 2      6.83               1.0         4   28     0   15   24
# 3      1.35               1.0         6   28     0   15   24
# 4      0.59               1.0         7   28     0   15   24
#
#    cab_provider_Uber  source_Beacon Hill  source_Boston University  ...  \
# 0                  0                   0                         0  ...
# 1                  0                   0                         0  ...
# 2                  1                   0                         0  ...
# 3                  1                   1                         0  ...
# 4                  0                   0                         0  ...
#
#    destination_Boston University  destination_Fenway  \
# 0                              0                   0
# 1                              0                   0
# ...

# %%
df_test.drop(['sec'], inplace = True, axis = 1)

# %%
# Create a scaling object
scaler = StandardScaler()

# Create a list of the variables that you need to scale
varlist = ['distance', 'surge_multiplier', 'cab_type', 'day', 'hour',
       'min']

# Scale these variables using 'fit_transform'
df_test[varlist] = scaler.fit_transform(df_test[varlist])

# %%
df_test[varlist].head()
# Out:
#    distance  surge_multiplier  cab_type  day      hour      min
# 0 -1.417087         -0.160302  0.445114  0.0 -2.686761 -0.98405
# 1 -1.417087         -0.160302  1.314726  0.0 -2.686761 -0.98405
# 2  4.152332         -0.160302 -0.714369  0.0 -2.686761 -0.98405
# 3 -0.738761         -0.160302 -0.134628  0.0 -2.686761 -0.98405
# 4 -1.417087         -0.160302  0.155243  0.0 -2.686761 -0.98405

# %%
df_test.head()
# Out:
#    distance  surge_multiplier  cab_type  day      hour      min  \
# 0 -1.417087         -0.160302  0.445114  0.0 -2.686761 -0.98405
# 1 -1.417087         -0.160302  1.314726  0.0 -2.686761 -0.98405
# 2  4.152332         -0.160302 -0.714369  0.0 -2.686761 -0.98405
# 3 -0.738761         -0.160302 -0.134628  0.0 -2.686761 -0.98405
# 4 -1.417087         -0.160302  0.155243  0.0 -2.686761 -0.98405
#
#    cab_provider_Uber  source_Beacon Hill  source_Boston University  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  1                   0                         0
# 3                  1                   1                         0
# 4                  0                   0                         0
#
#    source_Fenway  ...  destination_Boston University  destination_Fenway  \
# 0              0  ...                              0                   0
# ...

# %%
df_test.columns
# Out:
# Index(['distance', 'surge_multiplier', 'cab_type', 'day', 'hour', 'min',
#        'cab_provider_Uber', 'source_Beacon Hill', 'source_Boston University',
#        'source_Fenway', 'source_Financial District', 'source_Haymarket Square',
#        'source_North End', 'source_North Station',
#        'source_Northeastern University', 'source_South Station',
#        'source_Theatre District', 'source_West End', 'destination_Beacon Hill',
#        'destination_Boston University', 'destination_Fenway',
#        'destination_Financial District', 'destination_Haymarket Square',
#        'destination_North End', 'destination_North Station',
#        'destination_Northeastern University', 'destination_South Station',
#        'destination_Theatre District', 'destination_West End'],
#       dtype='object')

# %%
test.columns
# Out:
# Index(['distance', 'surge_multiplier', 'cab_type', 'day', 'hour', 'min',
#        'cab_provider_Uber', 'source_Beacon Hill', 'source_Boston University',
#        'source_Fenway', 'source_Financial District', 'source_Haymarket Square',
#        'source_North End', 'source_North Station',
#        'source_Northeastern University', 'source_South Station',
#        'source_Theatre District', 'source_West End', 'destination_Beacon Hill',
#        'destination_Boston University', 'destination_Fenway',
#        'destination_Financial District', 'destination_Haymarket Square',
#        'destination_North End', 'destination_North Station',
#        'destination_Northeastern University', 'destination_South Station',
#        'destination_Theatre District', 'destination_West End'],
#       dtype='object')

# %%
df_test = pd.concat([df_test[varlist], df_test_dummies], axis=1)
df_test.head()
# Out:
#    distance  surge_multiplier  cab_type  day      hour      min  \
# 0 -1.417087         -0.160302  0.445114  0.0 -2.686761 -0.98405
# 1 -1.417087         -0.160302  1.314726  0.0 -2.686761 -0.98405
# 2  4.152332         -0.160302 -0.714369  0.0 -2.686761 -0.98405
# 3 -0.738761         -0.160302 -0.134628  0.0 -2.686761 -0.98405
# 4 -1.417087         -0.160302  0.155243  0.0 -2.686761 -0.98405
#
#    cab_provider_Uber  source_Beacon Hill  source_Boston University  \
# 0                  0                   0                         0
# 1                  0                   0                         0
# 2                  1                   0                         0
# 3                  1                   1                         0
# 4                  0                   0                         0
#
#    source_Fenway  ...  destination_Boston University  destination_Fenway  \
# 0              0  ...                              0                   0
# ...

# %%
# Making predictions
y_pred_final = lm.predict(df_test)

# %%
y_pred_final
# Out:
# array([-0.19116211,  0.53463745,  0.89834595, ...,  1.60855103,
#        -1.17572021,  0.51779175])

# %%
fare_test_3 = pd.DataFrame(y_pred_final, columns = ['fare'])
fare_test_3.head()
# Out:
#        fare
# 0 -0.191162
# 1  0.534637
# 2  0.898346
# 3 -0.371704
# 4 -0.433075

# %%
fare_test_3.to_csv('F:\prediction sub.csv')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier
